# %% [markdown]
# Summary
#
#  Dive provides an interactive interface for exploring the relationship between data points across all of the different features of a dataset. Each individual item in the visualization represents a data point. Position items by "faceting" or bucketing them in multiple dimensions by their feature values. Success stories of Dive include the detection of classifier failure, identification of systematic errors, evaluating ground truth and potential new signals for ranking.
#
# The Dive visualization shows each individual item in the training dataset. Clicking on an individual item reveals key/value pairs that represent the features of that record; values may be strings or numbers.
#
# In this section, you'll learn how to use Dive embedded in your on page or app. The two things you need are your own data, and the Dive Polymer element.
# The facets-dive element has many attributes you can set to customize its behavior, but the only one you absolutely must set is data. This should be an array of JavaScript objects, where each object represents a single record.
# This demo was based on the demo below  https://github.com/PAIR-code/facets/tree/master/facets_dive

# %%
# Load data from https://covid.ourworldindata.org/data/ecdc/locations.csv and convert to json for sending to the visualization
# Load dataframe from external CSV and add header information
import pandas as pd
features = ["countriesAndTerritories", "location", "continent", "population_year","population"]
df = pd.read_csv(
    "https://covid.ourworldindata.org/data/ecdc/locations.csv",
    names=features
    )
jsonstr = df.to_json(orient='records')

# %%
# Display the Dive visualization for this data
from IPython.core.display import display, HTML

# Create Facets template  

HTML_TEMPLATE = \
    """
        <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
        <facets-dive id="elem_id" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem_id").data = data;
        </script>
    """

# Load the json dataset into the template
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
# Display the template
display(HTML(html))
# Out:
#         <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem_id" height="600"></facets-dive>
#         <script>
#           var data = [{"countriesAndTerritories":"countriesAndTerritories","location":"location","continent":"continent","population_year":"population_year","population":"population"},{"countriesAndTerritories":"Afghanistan","location":"Afghanistan","continent":"Asia","population_year":"2020","population":"38928341"},{"countriesAndTerritories":"Albania","location":"Albania","continent":"Europe","population_year":"2020","population":"2877800"},{"countriesAndTerritories":"Algeria","location":"Algeria","continent":"Africa","population_year":"2020","population":"43851043"},{"countriesAndTerritories":"Andorra","location":"Andorra","continent":"Europe","population_year":"2020","population":"77265"},{"countriesAndTerritories":"Angola","location":"Angola","continent":"Africa","population_year":"2020","population":"32866268"},{"countriesAndTerritories":"Anguilla","location":"Anguilla","continent":"North America","population_year":"2020","population":"15002"},{"countriesAndTerritories":"Antigua_and_Barbuda","location":"Antigua and Barbuda","continent":"North America","population_year":"2020","population":"97928"},{"countriesAndTerritories":"Argentina","location":"Argentina","continent":"South America","population_year":"2020","population":"45195777"},{"countriesAndTerritories":"Armenia","location":"Armenia","continent":"Asia","population_year":"2020","population":"2963234"},{"countriesAndTerritories":"Aruba","location":"Aruba","continent":"North America","population_year":"2020","population":"106766"},{"countriesAndTerritories":"Australia","location":"Australia","continent":"Oceania","population_year":"2020","population":"25499881"},{"countriesAndTerritories":"Austria","location":"Austria","continent":"Europe","population_year":"2020","population":"9006400"},{"countriesAndTerritories":"Azerbaijan","location":"Azerbaijan","continent":"Asia","population_year":"2020","population":"10139175"},{"countriesAndTerritories":"Bahamas","location":"Bahamas","continent":"North America","population_year":"2020","population":"393248"},{"countriesAndTerritories":"Bahrain","location":"Bahrain","continent":"Asia","population_year":"2020","population":"1701583"},{"countriesAndTerritories":"Bangladesh","location":"Bangladesh","continent":"Asia","population_year":"2020","population":"164689383"},{"countriesAndTerritories":"Barbados","location":"Barbados","continent":"North America","population_year":"2020","population":"287371"},{"countriesAndTerritories":"Belarus","location":"Belarus","continent":"Europe","population_year":"2020","population":"9449321"},{"countriesAndTerritories":"Belgium","location":"Belgium","continent":"Europe","population_year":"2020","population":"11589616"},{"countriesAndTerritories":"Belize","location":"Belize","continent":"North America","population_year":"2020","population":"397621"},{"countriesAndTerritories":"Benin","location":"Benin","continent":"Africa","population_year":"2020","population":"12123198"},{"countriesAndTerritories":"Bermuda","location":"Bermuda","continent":"North America","population_year":"2020","population":"62273"},{"countriesAndTerritories":"Bhutan","location":"Bhutan","continent":"Asia","population_year":"2020","population":"771612"},{"countriesAndTerritories":"Bolivia","location":"Bolivia","continent":"South America","population_year":"2020","population":"11673029"},{"countriesAndTerritories":"Bonaire, Saint Eustatius and Saba","location":"Bonaire Sint Eustatius and Saba","continent":"North America","population_year":"2020","population":"26221"},{"countriesAndTerritories":"Bosnia_and_Herzegovina","location":"Bosnia and Herzegovina","continent":"Europe","population_year":"2020","population":"3280815"},{"countriesAndTerritories":"Botswana","location":"Botswana","continent":"Africa","population_year":"2020","population":"2351625"},{"countriesAndTerritories":"Brazil","location":"Brazil","continent":"South America","population_year":"2020","population":"212559409"},{"countriesAndTerritories":"British_Virgin_Isl ...
